# %% [markdown]
# # csv

# %%
import pandas as pd

# %%
data = pd.read_csv('~/下载/day03/2.code/data/stock_day.csv',usecols = ['open','close'])#读取csv文件指定内容
data
# Out:
#              open  close
# 2018-02-27  23.53  24.16
# 2018-02-26  22.80  23.53
# 2018-02-23  22.88  22.82
# 2018-02-22  22.25  22.28
# 2018-02-14  21.49  21.92
# ...           ...    ...
# 2015-03-06  13.17  14.28
# 2015-03-05  12.88  13.16
# 2015-03-04  12.80  12.90
# 2015-03-03  12.52  12.70
# 2015-03-02  12.25  12.52
#
# [643 rows x 2 columns]

# %%
data.to_csv('~/文档/to/test.csv' , columns = ['close'])#写入 colusms为写入的值
pd.read_csv('~/文档/to/test.csv')
# Out:
#      Unnamed: 0  close
# 0    2018-02-27  24.16
# 1    2018-02-26  23.53
# 2    2018-02-23  22.82
# 3    2018-02-22  22.28
# 4    2018-02-14  21.92
# ..          ...    ...
# 638  2015-03-06  14.28
# 639  2015-03-05  13.16
# 640  2015-03-04  12.90
# 641  2015-03-03  12.70
# 642  2015-03-02  12.52
#
# [643 rows x 2 columns]

# %%
data.to_csv('~/文档/to/test2.csv' , columns = ['close'], index = False)#索引列不再写入
pd.read_csv('~/文档/to/test2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6ecff18e1660> in <module>
# ----> 1 data.to_csv('~/文档/to/test2.csv' , columns = ['close'], index_col = False)#索引列不再写入
#       2 pd.read_csv('~/文档/to/test2.csv')
#
# NameError: name 'data' is not defined

# %% [markdown]
# # hdf

# %%
day_close = pd.read_hdf('~/文档/read/day_close.h5')#读

# %%
day_close.head()
# Out:
#    000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0      16.30      17.71       4.58       2.88      14.60       2.62
# 1      17.02      19.20       4.65       3.02      15.97       2.65
# 2      17.02      17.28       4.56       3.06      14.37       2.63
# 3      16.18      16.97       4.49       2.95      13.10       2.73
# 4      16.95      17.19       4.55       2.99      13.18       2.77
#
#    000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# 0       4.96       4.66       5.37       6.02  ...        NaN        NaN
# 1       4.95       4.70       5.37       6.27  ...        NaN        NaN
# 2       4.82       4.47       5.37       5.96  ...        NaN        NaN
# 3       4.89       4.33       5.37       5.77  ...        NaN        NaN
# 4       4.97       4.42       5.37       5.92  ...        NaN        NaN
#
#    002920.SZ  002921.SZ  300684.SZ  002922.SZ  300735.SZ  603329.SH  \
# ...

# %%
day_close.to_hdf('~/文档/to/test3.h5',key = 'day_close')#在保存文件时定义key值为已存在列表 写

# %%
pd.read_hdf('~/文档/to/test3.h5' , key = 'day_close')
# Out:
#       000001.SZ  000002.SZ  000004.SZ  000005.SZ  000006.SZ  000007.SZ  \
# 0         16.30      17.71       4.58       2.88      14.60       2.62
# 1         17.02      19.20       4.65       3.02      15.97       2.65
# 2         17.02      17.28       4.56       3.06      14.37       2.63
# 3         16.18      16.97       4.49       2.95      13.10       2.73
# 4         16.95      17.19       4.55       2.99      13.18       2.77
# ...         ...        ...        ...        ...        ...        ...
# 2673      12.96      35.99      22.84       4.37       9.85      16.66
# 2674      13.08      35.84      23.02       4.41       9.85      16.66
# 2675      13.47      35.67      22.40       4.32       9.85      16.66
# 2676      13.40      35.15      22.29       4.29       9.85      16.66
# 2677      13.55      35.55      22.20       4.37       9.85      16.66
#
#       000008.SZ  000009.SZ  000010.SZ  000011.SZ  ...  001965.SZ  603283.SH  \
# ...

# %% [markdown]
# # JSON

# %%
data = pd.read_json('~/文档/read/Sarcasm_Headlines_Dataset.json',orient = 'records' , lines = True)#orient 是索引之间的读取关系 #lines是按行读取

# %%
data
# Out:
#                                             article_link  \
# 0      https://www.huffingtonpost.com/entry/versace-b...
# 1      https://www.huffingtonpost.com/entry/roseanne-...
# 2      https://local.theonion.com/mom-starting-to-fea...
# 3      https://politics.theonion.com/boehner-just-wan...
# 4      https://www.huffingtonpost.com/entry/jk-rowlin...
# ...                                                  ...
# 26704  https://www.huffingtonpost.com/entry/american-...
# 26705  https://www.huffingtonpost.com/entry/americas-...
# 26706  https://www.huffingtonpost.com/entry/reparatio...
# 26707  https://www.huffingtonpost.com/entry/israeli-b...
# 26708  https://www.huffingtonpost.com/entry/gourmet-g...
#
#                                                 headline  is_sarcastic
# 0      former versace store clerk sues over secret 'b...             0
# 1      the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
data.to_json('~/文档/to/test4.json' , orient='records' , lines=True)#写

# %% [markdown]
# # 判断文件是否存在

# %%
import os

# %%
os.path.exists('/Users/zhx/Documents/test_table.csv')
# Out:
# True

# %%
import pandas as pd
a = pd.read_csv(('/Users/zhx/Documents/test_table.csv'),index_col= False)

# %%
a
# Out:
#     Unnamed: 0     right      left      down            up
# 0            0  0.000000  0.000000  0.000000  0.000000e+00
# 1            1  0.000000  0.000000  0.000000  0.000000e+00
# 2            2  0.000000  0.000000  0.000000  0.000000e+00
# 3            3  0.000000  0.000000  0.000000  0.000000e+00
# 4            4  0.000000  0.000000  0.000000  0.000000e+00
# ..         ...       ...       ...       ...           ...
# 98      [4, 0]  0.000012  0.000002  0.000013  2.834823e-07
# 99      [4, 1]  0.000000  0.000002  0.000084  5.441956e-06
# 100     [0, 3]  0.000000  0.000000  0.000000  0.000000e+00
# 101     [5, 1]  0.000562  0.000015  0.000081  1.267455e-05
# 102     [5, 0]  0.000084  0.000015  0.000012  1.830074e-06
#
# [103 rows x 5 columns]

# %%
import numpy as np
q_table = pd.DataFrame(np.zeros([1, 4]), columns= ['right','left','down','up'])

# %%
print(q_table)
# Out:
#    right  left  down   up
# 0    0.0   0.0   0.0  0.0
